# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.read_csv("Rwanda Maize Production 2018.csv")
data
# Out:
#       District  S A Production (Ton)   S B Production (Ton)  \
# 0   Nyarugenge                    374                   275
# 1       Gasabo                  4,851                  1797
# 2     Kicukiro                  1,570                   504
# 3       Nyanza                  7,875                  2495
# 4     Gigasara                 16,057                  1922
# 5    Nyaruguru                  4,613                   453
# 6         Huye                  4,305                   644
# 7    Nyamagabe                  2,909                   966
# 8      Ruhango                  1,898                   962
# 9      Muhanga                  2,064                   458
# 10     Kamonyi                  6,555                  1634
# 11     Karongi                  5,732                   468
# 12     Rutsiro                  9,852                  2599
# 13      Rubavu                  5,394                  1354
# 14     Nyabihu                  4,902                  1706
# ...

# %%
data.head()
# Out:
#      District  S A Production (Ton)   S B Production (Ton)  \
# 0  Nyarugenge                    374                   275
# 1      Gasabo                  4,851                  1797
# 2    Kicukiro                  1,570                   504
# 3      Nyanza                  7,875                  2495
# 4    Gigasara                 16,057                  1922
#
#   Total Production (Ton)
# 0                    649
# 1                  6,648
# 2                  2,074
# 3                 10,370
# 4                 17,979

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   District                31 non-null     object
#  1    S A Production (Ton)   31 non-null     object
#  2   S B Production (Ton)    31 non-null     int64
#  3   Total Production (Ton)  31 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
data.tail()
# Out:
#     District  S A Production (Ton)   S B Production (Ton)  \
# 26   Kayonza                 20,181                  5546
# 27    Kirehe                 21,438                  4852
# 28     Ngoma                 23,020                  1947
# 29  Bugesera                 10,561                 13703
# 30     Total                333,477                 91533
#
#    Total Production (Ton)
# 26                 25,727
# 27                 26,290
# 28                 24,967
# 29                 24,264
# 30                425,010

# %%
data.isnull().sum()
# Out:
# District                  0
#  S A Production (Ton)     0
# S B Production (Ton)      0
# Total Production (Ton)    0
# dtype: int64

# %%
data=data.dropna()
data
# Out:
#       District  S A Production (Ton)   S B Production (Ton)  \
# 0   Nyarugenge                    374                   275
# 1       Gasabo                  4,851                  1797
# 2     Kicukiro                  1,570                   504
# 3       Nyanza                  7,875                  2495
# 4     Gigasara                 16,057                  1922
# 5    Nyaruguru                  4,613                   453
# 6         Huye                  4,305                   644
# 7    Nyamagabe                  2,909                   966
# 8      Ruhango                  1,898                   962
# 9      Muhanga                  2,064                   458
# 10     Kamonyi                  6,555                  1634
# 11     Karongi                  5,732                   468
# 12     Rutsiro                  9,852                  2599
# 13      Rubavu                  5,394                  1354
# 14     Nyabihu                  4,902                  1706
# ...
