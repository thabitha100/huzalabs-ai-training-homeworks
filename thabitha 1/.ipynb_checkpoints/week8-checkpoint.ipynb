# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.read_csv("Rwanda Maize Production 2018.csv")
data
# Out:
#       District  S A Production (Ton)   S B Production (Ton)  \
# 0   Nyarugenge                    374                   275
# 1       Gasabo                  4,851                  1797
# 2     Kicukiro                  1,570                   504
# 3       Nyanza                  7,875                  2495
# 4     Gigasara                 16,057                  1922
# 5    Nyaruguru                  4,613                   453
# 6         Huye                  4,305                   644
# 7    Nyamagabe                  2,909                   966
# 8      Ruhango                  1,898                   962
# 9      Muhanga                  2,064                   458
# 10     Kamonyi                  6,555                  1634
# 11     Karongi                  5,732                   468
# 12     Rutsiro                  9,852                  2599
# 13      Rubavu                  5,394                  1354
# 14     Nyabihu                  4,902                  1706
# 15   Ngororero                  6,111                   892
# 16      Rusizi                  7,946                   640
# 17  Nyamasheke                  3,627                   315
# 18     Rulindo                  9,355                   440
# 19     Gakenke                 15,903                   834
# 20     Musanze                  9,378                  1501
# 21      Burera                  9,467                  2515
# 22     Gicumbi                 11,005                  2909
# 23   Rwamagana                 15,889                  2166
# 24   Nyagatere                 50,793                 22787
# 25     Gatsibo                 39,852                 12249
# 26     Kayonza                 20,181                  5546
# 27      Kirehe                 21,438                  4852
# 28       Ngoma                 23,020                  1947
# 29    Bugesera                 10,561                 13703
# 30       Total                333,477                 91533
#
#    Total Production (Ton)
# 0                     649
# 1                   6,648
# 2                   2,074
# 3                  10,370
# 4                  17,979
# 5                   5,066
# 6                   4,949
# 7                   3,875
# 8                   2,860
# 9                   2,522
# 10                  8,189
# 11                  6,200
# 12                 12,451
# 13                  6,748
# 14                  6,608
# 15                  7,003
# 16                  8,586
# 17                  3,942
# 18                  9,795
# 19                 16,737
# 20                 10,879
# 21                 11,982
# 22                 13,914
# 23                 18,055
# 24                 73,580
# 25                 52,101
# 26                 25,727
# 27                 26,290
# 28                 24,967
# 29                 24,264
# 30                425,010

# %%
data1=data.iloc[0:30]
data1
# Out:
#       District  S A Production (Ton)   S B Production (Ton)  \
# 0   Nyarugenge                    374                   275
# 1       Gasabo                  4,851                  1797
# 2     Kicukiro                  1,570                   504
# 3       Nyanza                  7,875                  2495
# 4     Gigasara                 16,057                  1922
# 5    Nyaruguru                  4,613                   453
# 6         Huye                  4,305                   644
# 7    Nyamagabe                  2,909                   966
# 8      Ruhango                  1,898                   962
# 9      Muhanga                  2,064                   458
# 10     Kamonyi                  6,555                  1634
# 11     Karongi                  5,732                   468
# 12     Rutsiro                  9,852                  2599
# 13      Rubavu                  5,394                  1354
# 14     Nyabihu                  4,902                  1706
# 15   Ngororero                  6,111                   892
# 16      Rusizi                  7,946                   640
# 17  Nyamasheke                  3,627                   315
# 18     Rulindo                  9,355                   440
# 19     Gakenke                 15,903                   834
# 20     Musanze                  9,378                  1501
# 21      Burera                  9,467                  2515
# 22     Gicumbi                 11,005                  2909
# 23   Rwamagana                 15,889                  2166
# 24   Nyagatere                 50,793                 22787
# 25     Gatsibo                 39,852                 12249
# 26     Kayonza                 20,181                  5546
# 27      Kirehe                 21,438                  4852
# 28       Ngoma                 23,020                  1947
# 29    Bugesera                 10,561                 13703
#
#    Total Production (Ton)
# 0                     649
# 1                   6,648
# 2                   2,074
# 3                  10,370
# 4                  17,979
# 5                   5,066
# 6                   4,949
# 7                   3,875
# 8                   2,860
# 9                   2,522
# 10                  8,189
# 11                  6,200
# 12                 12,451
# 13                  6,748
# 14                  6,608
# 15                  7,003
# 16                  8,586
# 17                  3,942
# 18                  9,795
# 19                 16,737
# 20                 10,879
# 21                 11,982
# 22                 13,914
# 23                 18,055
# 24                 73,580
# 25                 52,101
# 26                 25,727
# 27                 26,290
# 28                 24,967
# 29                 24,264

# %%
data1.head()
# Out:
#      District  S A Production (Ton)   S B Production (Ton)  \
# 0  Nyarugenge                    374                   275
# 1      Gasabo                  4,851                  1797
# 2    Kicukiro                  1,570                   504
# 3      Nyanza                  7,875                  2495
# 4    Gigasara                 16,057                  1922
#
#   Total Production (Ton)
# 0                    649
# 1                  6,648
# 2                  2,074
# 3                 10,370
# 4                 17,979

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   District                30 non-null     object
#  1    S A Production (Ton)   30 non-null     object
#  2   S B Production (Ton)    30 non-null     int64
#  3   Total Production (Ton)  30 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ KB

# %%
data1.tail()
# Out:
#     District  S A Production (Ton)   S B Production (Ton)  \
# 25   Gatsibo                 39,852                 12249
# 26   Kayonza                 20,181                  5546
# 27    Kirehe                 21,438                  4852
# 28     Ngoma                 23,020                  1947
# 29  Bugesera                 10,561                 13703
#
#    Total Production (Ton)
# 25                 52,101
# 26                 25,727
# 27                 26,290
# 28                 24,967
# 29                 24,264

# %%
data1.isnull().sum()
# Out:
# District                  0
#  S A Production (Ton)     0
# S B Production (Ton)      0
# Total Production (Ton)    0
# dtype: int64

# %%
data1.describe()
# Out:
#        S B Production (Ton)
# count             30.000000
# mean            3051.100000
# std             4879.060045
# min              275.000000
# 25%              641.000000
# 50%             1567.500000
# 75%             2510.000000
# max            22787.000000

# %%
data1[" S A Production (Ton) "]=data1[" S A Production (Ton) "].astype(str)
data1["Total Production (Ton)"]=data1["Total Production (Ton)"].astype(str)

data1[" S A Production (Ton) "]=data1[" S A Production (Ton) "].str.replace(",","").astype(float)
data1["S B Production (Ton)"]=data1["S B Production (Ton)"].astype(float)
data1["Total Production (Ton)"]=data1["Total Production (Ton)"].str.replace(",","").astype(float)
data1
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9676\3938988555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[" S A Production (Ton) "]=data1[" S A Production (Ton) "].astype(str)
# C:\Users\PC\AppData\Local\Temp\ipykernel_9676\3938988555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Total Production (Ton)"]=data1["Total Production (Ton)"].astype(str)
# C:\Users\PC\AppData\Local\Temp\ipykernel_9676\3938988555.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[" S A Production (Ton) "]=data1[" S A Production (Ton) "].str.replace(",","").astype(float)
# C:\Users\PC\AppData\Local\Temp\ipykernel_9676\3938988555.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["S B Production (Ton)"]=data1["S B Production (Ton)"].astype(float)
# C:\Users\PC\AppData\Local\Temp\ipykernel_9676\3938988555.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Total Production (Ton)"]=data1["Total Production (Ton)"].str.replace(",","").astype(float)
#       District   S A Production (Ton)   S B Production (Ton)  \
# 0   Nyarugenge                   374.0                 275.0
# 1       Gasabo                  4851.0                1797.0
# 2     Kicukiro                  1570.0                 504.0
# 3       Nyanza                  7875.0                2495.0
# 4     Gigasara                 16057.0                1922.0
# 5    Nyaruguru                  4613.0                 453.0
# 6         Huye                  4305.0                 644.0
# 7    Nyamagabe                  2909.0                 966.0
# 8      Ruhango                  1898.0                 962.0
# 9      Muhanga                  2064.0                 458.0
# 10     Kamonyi                  6555.0                1634.0
# 11     Karongi                  5732.0                 468.0
# 12     Rutsiro                  9852.0                2599.0
# 13      Rubavu                  5394.0                1354.0
# 14     Nyabihu                  4902.0                1706.0
# 15   Ngororero                  6111.0                 892.0
# 16      Rusizi                  7946.0                 640.0
# 17  Nyamasheke                  3627.0                 315.0
# 18     Rulindo                  9355.0                 440.0
# 19     Gakenke                 15903.0                 834.0
# 20     Musanze                  9378.0                1501.0
# 21      Burera                  9467.0                2515.0
# 22     Gicumbi                 11005.0                2909.0
# 23   Rwamagana                 15889.0                2166.0
# 24   Nyagatere                 50793.0               22787.0
# 25     Gatsibo                 39852.0               12249.0
# 26     Kayonza                 20181.0                5546.0
# 27      Kirehe                 21438.0                4852.0
# 28       Ngoma                 23020.0                1947.0
# 29    Bugesera                 10561.0               13703.0
#
#     Total Production (Ton)
# 0                    649.0
# 1                   6648.0
# 2                   2074.0
# 3                  10370.0
# 4                  17979.0
# 5                   5066.0
# 6                   4949.0
# 7                   3875.0
# 8                   2860.0
# 9                   2522.0
# 10                  8189.0
# 11                  6200.0
# 12                 12451.0
# 13                  6748.0
# 14                  6608.0
# 15                  7003.0
# 16                  8586.0
# 17                  3942.0
# 18                  9795.0
# 19                 16737.0
# 20                 10879.0
# 21                 11982.0
# 22                 13914.0
# 23                 18055.0
# 24                 73580.0
# 25                 52101.0
# 26                 25727.0
# 27                 26290.0
# 28                 24967.0
# 29                 24264.0

# %%
top_maize_production_districts=data1.sort_values(by='Total Production (Ton)',ascending=False)
top_maize_production_districts
# Out:
#       District   S A Production (Ton)   S B Production (Ton)  \
# 24   Nyagatere                 50793.0               22787.0
# 25     Gatsibo                 39852.0               12249.0
# 27      Kirehe                 21438.0                4852.0
# 26     Kayonza                 20181.0                5546.0
# 28       Ngoma                 23020.0                1947.0
# 29    Bugesera                 10561.0               13703.0
# 23   Rwamagana                 15889.0                2166.0
# 4     Gigasara                 16057.0                1922.0
# 19     Gakenke                 15903.0                 834.0
# 22     Gicumbi                 11005.0                2909.0
# 12     Rutsiro                  9852.0                2599.0
# 21      Burera                  9467.0                2515.0
# 20     Musanze                  9378.0                1501.0
# 3       Nyanza                  7875.0                2495.0
# 18     Rulindo                  9355.0                 440.0
# 16      Rusizi                  7946.0                 640.0
# 10     Kamonyi                  6555.0                1634.0
# 15   Ngororero                  6111.0                 892.0
# 13      Rubavu                  5394.0                1354.0
# 1       Gasabo                  4851.0                1797.0
# 14     Nyabihu                  4902.0                1706.0
# 11     Karongi                  5732.0                 468.0
# 5    Nyaruguru                  4613.0                 453.0
# 6         Huye                  4305.0                 644.0
# 17  Nyamasheke                  3627.0                 315.0
# 7    Nyamagabe                  2909.0                 966.0
# 8      Ruhango                  1898.0                 962.0
# 9      Muhanga                  2064.0                 458.0
# 2     Kicukiro                  1570.0                 504.0
# 0   Nyarugenge                   374.0                 275.0
#
#     Total Production (Ton)
# 24                 73580.0
# 25                 52101.0
# 27                 26290.0
# 26                 25727.0
# 28                 24967.0
# 29                 24264.0
# 23                 18055.0
# 4                  17979.0
# 19                 16737.0
# 22                 13914.0
# 12                 12451.0
# 21                 11982.0
# 20                 10879.0
# 3                  10370.0
# 18                  9795.0
# 16                  8586.0
# 10                  8189.0
# 15                  7003.0
# 13                  6748.0
# 1                   6648.0
# 14                  6608.0
# 11                  6200.0
# 5                   5066.0
# 6                   4949.0
# 17                  3942.0
# 7                   3875.0
# 8                   2860.0
# 9                   2522.0
# 2                   2074.0
# 0                    649.0

# %%
import matplotlib as plt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))

plt.subplot(1, 3, 1)
sns.histplot(data1[' S A Production (Ton) '], kde=True)
plt.title(' S A Production (Ton) ')

plt.subplot(1, 3, 2)
sns.histplot(data1['S B Production (Ton)'], kde=True)
plt.title('S B Production (Ton)')

plt.subplot(1, 3, 3)
sns.histplot(data1['Total Production (Ton)'], kde=True)
plt.title('Total Production (Ton)')

plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(14, 7))

plt.subplot(1, 3, 1)
sns.boxplot(y=data1[' S A Production (Ton) '])
plt.title(' S A Production (Ton) ')

plt.subplot(1, 3, 2)
sns.boxplot(y=data1['S B Production (Ton)'])
plt.title('S B Production (Ton)')

plt.subplot(1, 3, 3)
sns.boxplot(y=data1['Total Production (Ton)'])
plt.title('Total Production (Ton)')

plt.tight_layout()
plt.show()
